# %%
from utilities import *
qubits = [ket0, ket1, ket_plus, ket_minus]

for basis in ['c', 'h']:
    if basis == 'c':
        bob_msmt_outcomes = [ket0, ket1]
    else:
        bob_msmt_outcomes = [ket_plus, ket_minus]

    for bob_qubit in bob_msmt_outcomes:
        # Alice could have sent one of these
        for alice_qubit in qubits:
            _ = animate_quantum_channel(alice_qubit, bob_qubit, basis)
